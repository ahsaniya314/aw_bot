# %% [markdown]
# # Pengujian Otomatis Sistem NLP Rule-Based & Fuzzy String Matching
#
# Notebook ini melakukan **pengujian otomatis** terhadap sistem NLP berbasis **Rule-Based** dan **Fuzzy String Matching** yang digunakan pada chatbot penjualan UMKM.
#
# Seluruh hasil prediksi berasal dari **pembacaan sistem yang sebenarnya** melalui fungsi `proses_nlp()`. Tidak ada prediksi manual, tidak ada modifikasi output, dan tidak ada penyesuaian terhadap Ground Truth.
#
# ---
#
# ### Tujuan Pengujian
#
# 1. **Identifikasi Intent** — Menguji kemampuan sistem mengenali maksud pengguna.
# 2. **Ekstraksi Entitas** — Menguji kemampuan sistem mengekstrak informasi dari teks.
#
# ### Metode Evaluasi
#
# | Metrik | Library |
# |---|---|
# | Confusion Matrix | `sklearn.metrics` |
# | Accuracy | `sklearn.metrics` |
# | Precision (macro) | `sklearn.metrics` |
# | Recall (macro) | `sklearn.metrics` |
# | F1-score (macro) | `sklearn.metrics` |
#
# ### Library yang Digunakan
#
# - `pandas`, `numpy`, `matplotlib`, `seaborn`, `scikit-learn`

# %% [markdown]
# ---
# ## 1. Import Library & Inisialisasi Sistem

# %%
import sys
import os
import re
import warnings
warnings.filterwarnings('ignore')

# Pastikan root project ada di sys.path agar modul NLP dapat diimpor
PROJECT_ROOT = os.path.abspath(os.getcwd())
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# Import fungsi NLP dari sistem yang sebenarnya
from nlp.processor import proses_nlp

# Konfigurasi tampilan
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 220)
plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 10
sns.set_style('whitegrid')

print("=" * 60)
print("INISIALISASI SISTEM")
print("=" * 60)
print(f"Project Root  : {PROJECT_ROOT}")
print(f"Waktu Eksekusi: {datetime.now().strftime('%d-%m-%Y %H:%M:%S')}")
print(f"Fungsi NLP    : proses_nlp() dari nlp.processor")
print("\n✅ Seluruh library dan modul NLP berhasil dimuat.")
# Out:
# ============================================================
# INISIALISASI SISTEM
# ============================================================
# Project Root  : C:\Users\FINN\Documents\BOT
# Waktu Eksekusi: 26-06-2026 20:35:43
# Fungsi NLP    : proses_nlp() dari nlp.processor
#
# ✅ Seluruh library dan modul NLP berhasil dimuat.

# %% [markdown]
# ---
# ## 2. Dataset Pengujian (20 Data Uji)

# %%
test_inputs = [
    "Halo bot",
    "Selamat pagi",
    "Cek penjualan hari ini",
    "Total uang masuk hari ini",
    "Tampilkan semua transaksi",
    "Tampilkan transaksi kemarin",
    "Tampilkan transaksi tanggal 21",
    "Cek hutang pak andi",
    "Tampilkan tagihan",
    "Berapa harga brownis",
    "Tambah barang brownis harga 2500 per bungkus",
    "Edit harga permen jadi 14000",
    "Hapus transaksi pak ardi",
    "Update transaksi udin jadi lunas",
    "Hari ini Budi ambil bembeng 40 ctn lunas tunai",
    "Kemarin Udin ambil meses 20 ctn dicicil 200000 tf",
    "06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn",
    "21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer",
    "Zio bayar hutang 270000 transfer",
    "Tambahan bayar pak andi 50rb tunai"
]

print(f"Total data uji: {len(test_inputs)}")
print("-" * 60)
for i, inp in enumerate(test_inputs, 1):
    print(f"  [{i:02d}] {inp}")
# Out:
# Total data uji: 20
# ------------------------------------------------------------
#   [01] Halo bot
#   [02] Selamat pagi
#   [03] Cek penjualan hari ini
#   [04] Total uang masuk hari ini
#   [05] Tampilkan semua transaksi
#   [06] Tampilkan transaksi kemarin
#   [07] Tampilkan transaksi tanggal 21
#   [08] Cek hutang pak andi
#   [09] Tampilkan tagihan
#   [10] Berapa harga brownis
#   [11] Tambah barang brownis harga 2500 per bungkus
#   [12] Edit harga permen jadi 14000
#   [13] Hapus transaksi pak ardi
#   [14] Update transaksi udin jadi lunas
#   [15] Hari ini Budi ambil bembeng 40 ctn lunas tunai
#   [16] Kemarin Udin ambil meses 20 ctn dicicil 200000 tf
#   [17] 06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn
#   [18] 21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer
#   [19] Zio bayar hutang 270000 transfer
#   [20] Tambahan bayar pak andi 50rb tunai

# %% [markdown]
# ---
# ## 3. Ground Truth
#
# Ground Truth berisi label yang benar untuk setiap input pengujian. Digunakan **hanya sebagai pembanding** terhadap hasil prediksi sistem.
#
# Komponen Ground Truth:
# - **Intent**: Label intent yang diharapkan
# - **Entitas**: tanggal, pelanggan, barang, jumlah, satuan, status, nominal, metode_pembayaran
# - Jika suatu entitas tidak ada, diisi dengan `None`

# %%
# Tanggal dinamis — dihitung saat notebook dijalankan
hari_ini = datetime.now()
tgl_hari_ini = hari_ini.strftime("%d-%m-%Y")
tgl_kemarin = (hari_ini - timedelta(days=1)).strftime("%d-%m-%Y")

# Tanggal 21: jika hari ini sudah lewat tgl 21, maka bulan ini; jika belum, bulan lalu
if 21 > hari_ini.day:
    bln21 = hari_ini.month - 1
    thn21 = hari_ini.year
    if bln21 == 0:
        bln21 = 12
        thn21 -= 1
else:
    bln21 = hari_ini.month
    thn21 = hari_ini.year
tgl_21 = f"21-{bln21:02d}-{thn21}"

ground_truth = [
    # 1. Halo bot
    {"intent": "Chit_Chat",
     "tanggal": None, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 2. Selamat pagi
    {"intent": "Chit_Chat",
     "tanggal": None, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 3. Cek penjualan hari ini
    {"intent": "Read_Analitik_Penjualan",
     "tanggal": tgl_hari_ini, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 4. Total uang masuk hari ini
    {"intent": "Read_Analitik_Penjualan",
     "tanggal": tgl_hari_ini, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 5. Tampilkan semua transaksi
    {"intent": "Read_Transaksi_Spesifik",
     "tanggal": None, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 6. Tampilkan transaksi kemarin
    {"intent": "Read_Transaksi_Spesifik",
     "tanggal": tgl_kemarin, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 7. Tampilkan transaksi tanggal 21
    {"intent": "Read_Transaksi_Spesifik",
     "tanggal": tgl_21, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 8. Cek hutang pak andi
    {"intent": "Read_Analitik_Hutang",
     "tanggal": None, "pelanggan": "Pak Andi", "barang": None, "jumlah": None,
     "satuan": None, "status": "Hutang", "nominal": None, "metode": None},

    # 9. Tampilkan tagihan
    {"intent": "Read_Analitik_Hutang",
     "tanggal": None, "pelanggan": None, "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 10. Berapa harga brownis
    {"intent": "CRUD_Barang",
     "tanggal": None, "pelanggan": None, "barang": "Brownis", "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 11. Tambah barang brownis harga 2500 per bungkus
    {"intent": "CRUD_Barang",
     "tanggal": None, "pelanggan": None, "barang": "Brownis", "jumlah": None,
     "satuan": "bungkus", "status": None, "nominal": None, "metode": None},

    # 12. Edit harga permen jadi 14000
    {"intent": "CRUD_Barang",
     "tanggal": None, "pelanggan": None, "barang": "Lolipop", "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 13. Hapus transaksi pak ardi
    {"intent": "Update_Delete_Transaksi",
     "tanggal": None, "pelanggan": "Pak Ardi", "barang": None, "jumlah": None,
     "satuan": None, "status": None, "nominal": None, "metode": None},

    # 14. Update transaksi udin jadi lunas
    {"intent": "Update_Delete_Transaksi",
     "tanggal": None, "pelanggan": "Udin", "barang": None, "jumlah": None,
     "satuan": None, "status": "Lunas", "nominal": None, "metode": None},

    # 15. Hari ini Budi ambil bembeng 40 ctn lunas tunai
    {"intent": "Catat_Penjualan_Lunas",
     "tanggal": tgl_hari_ini, "pelanggan": "Budi", "barang": "Bembeng",
     "jumlah": "40", "satuan": "karton", "status": "Lunas",
     "nominal": None, "metode": "Tunai"},

    # 16. Kemarin Udin ambil meses 20 ctn dicicil 200000 tf
    {"intent": "Catat_Penjualan_Cicil",
     "tanggal": tgl_kemarin, "pelanggan": "Udin", "barang": "Meses",
     "jumlah": "20", "satuan": "karton", "status": "Dicicil",
     "nominal": "Rp 200.000", "metode": "Transfer"},

    # 17. 06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn
    {"intent": "Catat_Penjualan_Lunas",
     "tanggal": "06-2026", "pelanggan": "Budi", 
     "barang": ["Bembeng", "Meses", "Willo"],
     "jumlah": ["40", "20", "100"],
     "satuan": ["karton", "karton", "karton"],
     "status": None, "nominal": None, "metode": None},

    # 18. 21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer
    {"intent": "Catat_Penjualan_Cicil",
     "tanggal": "21-04-2026", "pelanggan": "Andi", "barang": "Lolipop",
     "jumlah": "10", "satuan": "dus", "status": "Dicicil",
     "nominal": "Rp 50.000", "metode": "Transfer"},

    # 19. Zio bayar hutang 270000 transfer
    {"intent": "Pelunasan_Hutang",
     "tanggal": None, "pelanggan": "Zio", "barang": None, "jumlah": None,
     "satuan": None, "status": "Dicicil",
     "nominal": "Rp 270.000", "metode": "Transfer"},

    # 20. Tambahan bayar pak andi 50rb tunai
    {"intent": "Pelunasan_Hutang",
     "tanggal": None, "pelanggan": "Pak Andi", "barang": None, "jumlah": None,
     "satuan": None, "status": "Dicicil",
     "nominal": "Rp 50.000", "metode": "Tunai"}
]

# Buat DataFrame Ground Truth
df_gt = pd.DataFrame(ground_truth)
df_gt.insert(0, 'No', range(1, len(df_gt) + 1))
df_gt.insert(1, 'Input', test_inputs)

print("✅ Ground Truth berhasil dibuat.")
print(f"   Jumlah data        : {len(df_gt)}")
print(f"   Jumlah jenis intent: {df_gt['intent'].nunique()}")
print(f"   Jenis entitas      : {len([c for c in df_gt.columns if c not in ['No','Input','intent']])}")
print()
df_gt
# Out:
# ✅ Ground Truth berhasil dibuat.
#    Jumlah data        : 20
#    Jumlah jenis intent: 9
#    Jenis entitas      : 8
#     No                                                                Input                   intent     tanggal pelanggan                   barang         jumlah                    satuan   status     nominal  \
# 0    1                                                             Halo bot                Chit_Chat        None      None                     None           None                      None     None        None
# 1    2                                                         Selamat pagi                Chit_Chat        None      None                     None           None                      None     None        None
# 2    3                                               Cek penjualan hari ini  Read_Analitik_Penjualan  26-06-2026      None                     None           None                      None     None        None
# 3    4                                            Total uang masuk hari ini  Read_Analitik_Penjualan  26-06-2026      None                     None           None                      None     None        None
# 4    5                                            Tampilkan semua transaksi  Read_Transaksi_Spesifik        None      None                     None           None                      None     None        None
# 5    6                                          Tampilkan transaksi kemarin  Read_Transaksi_Spesifik  25-06-2026      None                     None           None                      None     None        None
# 6    7                                       Tampilkan transaksi tanggal 21  Read_Transaksi_Spesifik  21-06-2026      None                     None           None                      None     None        None
# 7    8                                                  Cek hutang pak andi     Read_Analitik_Hutang        None  Pak Andi                     None           None                      None   Hutang        None
# 8    9                                                    Tampilkan tagihan     Read_Analitik_Hutang        None      None                     None           None                      None     None        None
# 9   10                                                 Berapa harga brownis              CRUD_Barang        None      None                  Brownis           None                      None     None        None
# 10  11                         Tambah barang brownis harga 2500 per bungkus              CRUD_Barang        None      None                  Brownis           None                   bungkus     None        None
# 11  12                                         Edit harga permen jadi 14000              CRUD_Barang        None      None                  Lolipop           None                      None     None        None
# 12  13                                             Hapus transaksi pak ardi  Update_Delete_Transaksi        None  Pak Ardi                     None           None                      None     None        None
# 13  14                                     Update transaksi udin jadi lunas  Update_Delete_Transaksi        None      Udin                     None           None                      None    Lunas        None
# 14  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai    Catat_Penjualan_Lunas  26-06-2026      Budi                  Bembeng             40                    karton    Lunas        None
# 15  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf    Catat_Penjualan_Cicil  25-06-2026      Udin                    Meses             20                    karton  Dicicil  Rp 200.000
# 16  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn    Catat_Penjualan_Lunas     06-2026      Budi  [Bembeng, Meses, Willo]  [40, 20, 100]  [karton, karton, karton]     None        None
# 17  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer    Catat_Penjualan_Cicil  21-04-2026      Andi                  Lolipop             10                       dus  Dicicil   Rp 50.000
# 18  19                                     Zio bayar hutang 270000 transfer         Pelunasan_Hutang        None       Zio                     None           None                      None  Dicicil  Rp 270.000
# 19  20                                   Tambahan bayar pak andi 50rb tunai         Pelunasan_Hutang        None  Pak Andi                     None           None                      None  Dicicil   Rp 50.000
#
#       metode
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14     Tunai
# 15  Transfer
# 16      None
# 17  Transfer
# 18  Transfer
# 19     Tunai

# %% [markdown]
# ---
# ## 4. Pengujian Sistem — Menjalankan Pipeline NLP yang Sebenarnya
#
# Untuk setiap input, sistem menjalankan seluruh pipeline NLP melalui fungsi `proses_nlp()`:
#
# 1. **Normalisasi teks** — Koreksi typo dan slang (`koreksi_teks()`)
# 2. **Ekstraksi entitas** — Rule-Based + Regex (`ekstrak_entitas()`)
# 3. **Penentuan intent** — Fuzzy String Matching + Rule-Based (`tentukan_intent()`)
#
# Hasil prediksi disimpan **apa adanya** tanpa modifikasi apapun.
#
# > ⚠️ Jika sistem salah mengenali intent atau entitas, hasil yang salah tetap disimpan.

# %%
def jalankan_prediksi(inputs):
    """
    Menjalankan pipeline NLP yang sebenarnya (proses_nlp) untuk setiap input.
    Hasil disimpan apa adanya tanpa modifikasi.
    """
    prediksi_list = []

    for i, teks in enumerate(inputs):
        teks_display = teks[:55] + '...' if len(teks) > 55 else teks
        print(f"  [{i+1:02d}] Memproses: {teks_display}")

        try:
            # ===== MENJALANKAN PIPELINE NLP YANG SEBENARNYA =====
            hasil = proses_nlp(teks)
            # ====================================================

            if hasil and len(hasil) > 0:
                first_ent = hasil[0].get("entitas", {})
                intent_pred = hasil[0].get("intent", "Unknown")
                
                # Single-value fields
                tanggal = first_ent.get("TANGGAL")
                pelanggan = first_ent.get("NAMA")
                status = first_ent.get("STATUS")
                nominal = first_ent.get("NOMINAL_BAYAR")
                metode = first_ent.get("METODE_PEMBAYARAN")
                
                # Multi-value fields (list-based)
                barang = [r.get("entitas", {}).get("BARANG") for r in hasil if r.get("entitas", {}).get("BARANG") is not None]
                satuan = [r.get("entitas", {}).get("SATUAN") for r in hasil if r.get("entitas", {}).get("SATUAN") is not None]
                
                jumlah = []
                for r in hasil:
                    j_raw = r.get("entitas", {}).get("JUMLAH")
                    if j_raw is not None:
                        jumlah.append(j_raw)

                prediksi_list.append({
                    "intent": intent_pred,
                    "tanggal": tanggal,
                    "pelanggan": pelanggan,
                    "barang": barang,
                    "jumlah": jumlah,
                    "satuan": satuan,
                    "status": status,
                    "nominal": nominal,
                    "metode": metode
                })
            else:
                prediksi_list.append({
                    "intent": "Unknown",
                    "tanggal": None, "pelanggan": None, "barang": [],
                    "jumlah": [], "satuan": [], "status": None,
                    "nominal": None, "metode": None
                })

        except Exception as e:
            print(f"       ⚠️ Error pada input [{i+1}]: {e}")
            prediksi_list.append({
                "intent": "ERROR",
                "tanggal": None, "pelanggan": None, "barang": [],
                "jumlah": [], "satuan": [], "status": None,
                "nominal": None, "metode": None
            })

    return prediksi_list


print("=" * 60)
print("MENJALANKAN PIPELINE NLP UNTUK 20 DATA UJI")
print("=" * 60)
print()

prediksi = jalankan_prediksi(test_inputs)

print()
print(f"✅ Prediksi selesai. Total hasil: {len(prediksi)}")
print("   Seluruh hasil berasal dari sistem tanpa modifikasi.")
# Out:
# ============================================================
# MENJALANKAN PIPELINE NLP UNTUK 20 DATA UJI
# ============================================================
#
#   [01] Memproses: Halo bot
#   [02] Memproses: Selamat pagi
#   [03] Memproses: Cek penjualan hari ini
#   [04] Memproses: Total uang masuk hari ini
#   [05] Memproses: Tampilkan semua transaksi
#   [06] Memproses: Tampilkan transaksi kemarin
#   [07] Memproses: Tampilkan transaksi tanggal 21
#   [08] Memproses: Cek hutang pak andi
#   [09] Memproses: Tampilkan tagihan
#   [10] Memproses: Berapa harga brownis
#   [11] Memproses: Tambah barang brownis harga 2500 per bungkus
#   [12] Memproses: Edit harga permen jadi 14000
#   [13] Memproses: Hapus transaksi pak ardi
#   [14] Memproses: Update transaksi udin jadi lunas
#   [15] Memproses: Hari ini Budi ambil bembeng 40 ctn lunas tunai
#   [16] Memproses: Kemarin Udin ambil meses 20 ctn dicicil 200000 tf
#   [17] Memproses: 06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn w...
#   [18] Memproses: 21/04/2026 Andi ambil permen 10 dus dicicil 50000 trans...
#   [19] Memproses: Zio bayar hutang 270000 transfer
#   [20] Memproses: Tambahan bayar pak andi 50rb tunai
#
# ✅ Prediksi selesai. Total hasil: 20
#    Seluruh hasil berasal dari sistem tanpa modifikasi.

# %% [markdown]
# ---
# ## 5. Tabel Hasil Prediksi
#
# Tabel berikut membandingkan **Ground Truth** dengan **Prediksi Sistem** secara berdampingan.
#
# > ⚠️ Hasil prediksi ditampilkan **apa adanya** tanpa koreksi apapun.

# %%
def format_entitas_ringkas(data_dict):
    """Format dictionary entitas menjadi string ringkas untuk tabel."""
    fields = [
        ('tanggal', 'Tgl'), ('pelanggan', 'Plg'), ('barang', 'Brg'),
        ('jumlah', 'Jml'), ('satuan', 'Sat'), ('status', 'Sts'),
        ('nominal', 'Nom'), ('metode', 'Met')
    ]
    parts = []
    for key, label in fields:
        val = data_dict.get(key)
        if isinstance(val, list):
            if val:
                val_str = ", ".join([str(x) for x in val if x is not None])
                if val_str:
                    parts.append(f"{label}=[{val_str}]")
        else:
            if val is not None and str(val).strip() not in ('', 'None'):
                parts.append(f"{label}={val}")
    return ' | '.join(parts) if parts else '—'


# Buat tabel perbandingan
tabel_data = []
for i in range(len(test_inputs)):
    gt = ground_truth[i]
    pred = prediksi[i]

    tabel_data.append({
        'No': i + 1,
        'Input': test_inputs[i],
        'Ground Truth Intent': gt['intent'],
        'Prediksi Intent': pred['intent'],
        'Ground Truth Entitas': format_entitas_ringkas(gt),
        'Prediksi Entitas': format_entitas_ringkas(pred)
    })

df_tabel = pd.DataFrame(tabel_data)

print("=" * 100)
print("TABEL PERBANDINGAN: GROUND TRUTH vs PREDIKSI SISTEM")
print("=" * 100)
print()
df_tabel
# Out:
# ====================================================================================================
# TABEL PERBANDINGAN: GROUND TRUTH vs PREDIKSI SISTEM
# ====================================================================================================
#     No                                                                Input      Ground Truth Intent          Prediksi Intent  \
# 0    1                                                             Halo bot                Chit_Chat                Chit_Chat
# 1    2                                                         Selamat pagi                Chit_Chat                Chit_Chat
# 2    3                                               Cek penjualan hari ini  Read_Analitik_Penjualan  Read_Analitik_Penjualan
# 3    4                                            Total uang masuk hari ini  Read_Analitik_Penjualan  Read_Analitik_Penjualan
# 4    5                                            Tampilkan semua transaksi  Read_Transaksi_Spesifik  Read_Transaksi_Spesifik
# 5    6                                          Tampilkan transaksi kemarin  Read_Transaksi_Spesifik  Read_Transaksi_Spesifik
# 6    7                                       Tampilkan transaksi tanggal 21  Read_Transaksi_Spesifik  Read_Transaksi_Spesifik
# 7    8                                                  Cek hutang pak andi     Read_Analitik_Hutang     Read_Analitik_Hutang
# 8    9                                                    Tampilkan tagihan     Read_Analitik_Hutang     Read_Analitik_Hutang
# 9   10                                                 Berapa harga brownis              CRUD_Barang              CRUD_Barang
# 10  11                         Tambah barang brownis harga 2500 per bungkus              CRUD_Barang              CRUD_Barang
# 11  12                                         Edit harga permen jadi 14000              CRUD_Barang              CRUD_Barang
# 12  13                                             Hapus transaksi pak ardi  Update_Delete_Transaksi  Update_Delete_Transaksi
# 13  14                                     Update transaksi udin jadi lunas  Update_Delete_Transaksi  Update_Delete_Transaksi
# 14  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai    Catat_Penjualan_Lunas    Catat_Penjualan_Lunas
# 15  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf    Catat_Penjualan_Cicil    Catat_Penjualan_Cicil
# 16  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn    Catat_Penjualan_Lunas    Catat_Penjualan_Lunas
# 17  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer    Catat_Penjualan_Cicil    Catat_Penjualan_Cicil
# 18  19                                     Zio bayar hutang 270000 transfer         Pelunasan_Hutang  Read_Transaksi_Spesifik
# 19  20                                   Tambahan bayar pak andi 50rb tunai         Pelunasan_Hutang         Pelunasan_Hutang
#
#                                                                                    Ground Truth Entitas                                                                                     Prediksi Entitas
# 0                                                                                                     —                                                                                         Plg=Halo Bot
# 1                                                                                                     —                                                                                          Plg=Selamat
# 2                                                                                        Tgl=26-06-2026                                                                                       Tgl=26-06-2026
# 3                                                                                        Tgl=26-06-2026                                                                          Tgl=26-06-2026 | Sts=Hutang
# 4                                                                                                     —                                                                                                    —
# 5                                                                                        Tgl=25-06-2026                                                                                       Tgl=25-06-2026
# 6                                                                                        Tgl=21-06-2026                                                                                       Tgl=21-06-2026
# 7                                                                             Plg=Pak Andi | Sts=Hutang                                                                            Plg=Pak Andi | Sts=Hutang
# 8                                                                                                     —                                                                                           Sts=Hutang
# 9                                                                                           Brg=Brownis                                                                                        Brg=[Brownis]
# 10                                                                            Brg=Brownis | Sat=bungkus                                                                              Plg=Per | Brg=[Brownis]
# 11                                                                                          Brg=Lolipop                                                                                        Brg=[Lolipop]
# 12                                                                                         Plg=Pak Ardi                                                                                         Plg=Pak Ardi
# 13                                                                                 Plg=Udin | Sts=Lunas                                                                                 Plg=Udin | Sts=Lunas
# 14                Tgl=26-06-2026 | Plg=Budi | Brg=Bembeng | Jml=40 | Sat=karton | Sts=Lunas | Met=Tunai   Tgl=26-06-2026 | Plg=Budi | Brg=[Bembeng] | Jml=[40 karton] | Sat=[karton] | Sts=Lunas | Met=Tunai
# 15  Tgl=25-06-2026 | Plg=Udin | Brg=Meses | Jml=20 | Sat=karton | Sts=Dicicil | Nom=Rp 200.000 | Met...  Tgl=25-06-2026 | Plg=Udin | Brg=[Meses] | Jml=[20 karton] | Sat=[karton] | Sts=Dicicil | Nom=Rp ...
# 16  Tgl=06-2026 | Plg=Budi | Brg=[Bembeng, Meses, Willo] | Jml=[40, 20, 100] | Sat=[karton, karton, ...                                     Plg=O62O26 Budi | Brg=[Bembeng] | Jml=[40 karton] | Sat=[karton]
# 17  Tgl=21-04-2026 | Plg=Andi | Brg=Lolipop | Jml=10 | Sat=dus | Sts=Dicicil | Nom=Rp 50.000 | Met=T...  Plg=2Lo42O26 Andi | Brg=[Lolipop] | Jml=[10 dus] | Sat=[dus] | Sts=Dicicil | Nom=Rp 50.000 | Met...
# 18                                                Plg=Zio | Sts=Dicicil | Nom=Rp 270.000 | Met=Transfer                                                Plg=Zio | Sts=Dicicil | Nom=Rp 270.000 | Met=Transfer
# 19                                               Plg=Pak Andi | Sts=Dicicil | Nom=Rp 50.000 | Met=Tunai                                               Plg=Pak Andi | Sts=Dicicil | Nom=Rp 50.000 | Met=Tunai

# %%
# Detail perbandingan per baris untuk analisis mendalam
ENTITY_FIELDS = ['tanggal', 'pelanggan', 'barang', 'jumlah', 'satuan', 'status', 'nominal', 'metode']

print("=" * 100)
print("DETAIL PERBANDINGAN PER INPUT")
print("=" * 100)

for i in range(len(test_inputs)):
    gt = ground_truth[i]
    pred = prediksi[i]

    intent_ok = "✅" if gt['intent'] == pred['intent'] else "❌"

    print(f"\n[{i+1:02d}] {test_inputs[i]}")
    print(f"     Intent     : GT = {gt['intent']:<30s} | Pred = {pred['intent']:<30s} {intent_ok}")

    for field in ENTITY_FIELDS:
        gt_val = str(gt.get(field)) if gt.get(field) is not None else 'None'
        pred_val = str(pred.get(field)) if pred.get(field) is not None else 'None'
        
        # Simple match check for print display
        # List field check
        if isinstance(gt.get(field), list) or isinstance(pred.get(field), list):
            import copy
            g_list = sorted([str(x).lower().strip() for x in (gt.get(field) if isinstance(gt.get(field), list) else [gt.get(field)]) if x is not None])
            p_list = sorted([str(x).lower().strip() for x in (pred.get(field) if isinstance(pred.get(field), list) else [pred.get(field)]) if x is not None])
            match = "✅" if g_list == p_list else "❌"
        else:
            g_str = str(gt.get(field)).strip().lower()
            p_str = str(pred.get(field)).strip().lower()
            match = "✅" if g_str == p_str or (g_str in ('none', '') and p_str in ('none', '')) else "❌"
            
        print(f"     {field:<20s}: GT = {gt_val:<25s} | Pred = {pred_val:<25s} {match}")
# Out:
# ====================================================================================================
# DETAIL PERBANDINGAN PER INPUT
# ====================================================================================================
#
# [01] Halo bot
#      Intent     : GT = Chit_Chat                      | Pred = Chit_Chat                      ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = None                      | Pred = Halo Bot                  ❌
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [02] Selamat pagi
#      Intent     : GT = Chit_Chat                      | Pred = Chit_Chat                      ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = None                      | Pred = Selamat                   ❌
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [03] Cek penjualan hari ini
#      Intent     : GT = Read_Analitik_Penjualan        | Pred = Read_Analitik_Penjualan        ✅
#      tanggal             : GT = 26-06-2026                | Pred = 26-06-2026                ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [04] Total uang masuk hari ini
#      Intent     : GT = Read_Analitik_Penjualan        | Pred = Read_Analitik_Penjualan        ✅
#      tanggal             : GT = 26-06-2026                | Pred = 26-06-2026                ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = Hutang                    ❌
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [05] Tampilkan semua transaksi
#      Intent     : GT = Read_Transaksi_Spesifik        | Pred = Read_Transaksi_Spesifik        ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [06] Tampilkan transaksi kemarin
#      Intent     : GT = Read_Transaksi_Spesifik        | Pred = Read_Transaksi_Spesifik        ✅
#      tanggal             : GT = 25-06-2026                | Pred = 25-06-2026                ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [07] Tampilkan transaksi tanggal 21
#      Intent     : GT = Read_Transaksi_Spesifik        | Pred = Read_Transaksi_Spesifik        ✅
#      tanggal             : GT = 21-06-2026                | Pred = 21-06-2026                ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [08] Cek hutang pak andi
#      Intent     : GT = Read_Analitik_Hutang           | Pred = Read_Analitik_Hutang           ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = Pak Andi                  | Pred = Pak Andi                  ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = Hutang                    | Pred = Hutang                    ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [09] Tampilkan tagihan
#      Intent     : GT = Read_Analitik_Hutang           | Pred = Read_Analitik_Hutang           ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = Hutang                    ❌
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [10] Berapa harga brownis
#      Intent     : GT = CRUD_Barang                    | Pred = CRUD_Barang                    ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = Brownis                   | Pred = ['Brownis']               ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [11] Tambah barang brownis harga 2500 per bungkus
#      Intent     : GT = CRUD_Barang                    | Pred = CRUD_Barang                    ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = None                      | Pred = Per                       ❌
#      barang              : GT = Brownis                   | Pred = ['Brownis']               ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = bungkus                   | Pred = []                        ❌
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [12] Edit harga permen jadi 14000
#      Intent     : GT = CRUD_Barang                    | Pred = CRUD_Barang                    ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = None                      | Pred = None                      ✅
#      barang              : GT = Lolipop                   | Pred = ['Lolipop']               ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [13] Hapus transaksi pak ardi
#      Intent     : GT = Update_Delete_Transaksi        | Pred = Update_Delete_Transaksi        ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = Pak Ardi                  | Pred = Pak Ardi                  ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [14] Update transaksi udin jadi lunas
#      Intent     : GT = Update_Delete_Transaksi        | Pred = Update_Delete_Transaksi        ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = Udin                      | Pred = Udin                      ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = Lunas                     | Pred = Lunas                     ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [15] Hari ini Budi ambil bembeng 40 ctn lunas tunai
#      Intent     : GT = Catat_Penjualan_Lunas          | Pred = Catat_Penjualan_Lunas          ✅
#      tanggal             : GT = 26-06-2026                | Pred = 26-06-2026                ✅
#      pelanggan           : GT = Budi                      | Pred = Budi                      ✅
#      barang              : GT = Bembeng                   | Pred = ['Bembeng']               ✅
#      jumlah              : GT = 40                        | Pred = ['40 karton']             ❌
#      satuan              : GT = karton                    | Pred = ['karton']                ✅
#      status              : GT = Lunas                     | Pred = Lunas                     ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = Tunai                     | Pred = Tunai                     ✅
#
# [16] Kemarin Udin ambil meses 20 ctn dicicil 200000 tf
#      Intent     : GT = Catat_Penjualan_Cicil          | Pred = Catat_Penjualan_Cicil          ✅
#      tanggal             : GT = 25-06-2026                | Pred = 25-06-2026                ✅
#      pelanggan           : GT = Udin                      | Pred = Udin                      ✅
#      barang              : GT = Meses                     | Pred = ['Meses']                 ✅
#      jumlah              : GT = 20                        | Pred = ['20 karton']             ❌
#      satuan              : GT = karton                    | Pred = ['karton']                ✅
#      status              : GT = Dicicil                   | Pred = Dicicil                   ✅
#      nominal             : GT = Rp 200.000                | Pred = Rp 200.000                ✅
#      metode              : GT = Transfer                  | Pred = Transfer                  ✅
#
# [17] 06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn
#      Intent     : GT = Catat_Penjualan_Lunas          | Pred = Catat_Penjualan_Lunas          ✅
#      tanggal             : GT = 06-2026                   | Pred = None                      ❌
#      pelanggan           : GT = Budi                      | Pred = O62O26 Budi               ❌
#      barang              : GT = ['Bembeng', 'Meses', 'Willo'] | Pred = ['Bembeng']               ❌
#      jumlah              : GT = ['40', '20', '100']       | Pred = ['40 karton']             ❌
#      satuan              : GT = ['karton', 'karton', 'karton'] | Pred = ['karton']                ❌
#      status              : GT = None                      | Pred = None                      ✅
#      nominal             : GT = None                      | Pred = None                      ✅
#      metode              : GT = None                      | Pred = None                      ✅
#
# [18] 21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer
#      Intent     : GT = Catat_Penjualan_Cicil          | Pred = Catat_Penjualan_Cicil          ✅
#      tanggal             : GT = 21-04-2026                | Pred = None                      ❌
#      pelanggan           : GT = Andi                      | Pred = 2Lo42O26 Andi             ❌
#      barang              : GT = Lolipop                   | Pred = ['Lolipop']               ✅
#      jumlah              : GT = 10                        | Pred = ['10 dus']                ❌
#      satuan              : GT = dus                       | Pred = ['dus']                   ✅
#      status              : GT = Dicicil                   | Pred = Dicicil                   ✅
#      nominal             : GT = Rp 50.000                 | Pred = Rp 50.000                 ✅
#      metode              : GT = Transfer                  | Pred = Transfer                  ✅
#
# [19] Zio bayar hutang 270000 transfer
#      Intent     : GT = Pelunasan_Hutang               | Pred = Read_Transaksi_Spesifik        ❌
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = Zio                       | Pred = Zio                       ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = Dicicil                   | Pred = Dicicil                   ✅
#      nominal             : GT = Rp 270.000                | Pred = Rp 270.000                ✅
#      metode              : GT = Transfer                  | Pred = Transfer                  ✅
#
# [20] Tambahan bayar pak andi 50rb tunai
#      Intent     : GT = Pelunasan_Hutang               | Pred = Pelunasan_Hutang               ✅
#      tanggal             : GT = None                      | Pred = None                      ✅
#      pelanggan           : GT = Pak Andi                  | Pred = Pak Andi                  ✅
#      barang              : GT = None                      | Pred = []                        ✅
#      jumlah              : GT = None                      | Pred = []                        ✅
#      satuan              : GT = None                      | Pred = []                        ✅
#      status              : GT = Dicicil                   | Pred = Dicicil                   ✅
#      nominal             : GT = Rp 50.000                 | Pred = Rp 50.000                 ✅
#      metode              : GT = Tunai                     | Pred = Tunai                     ✅

# %% [markdown]
# ---
# ## 6. Evaluasi Identifikasi Intent
#
# Membandingkan **Ground Truth Intent** dengan **Prediksi Intent** menggunakan `sklearn.metrics`.
#
# Metrik dihitung dengan `average='macro'` untuk memperlakukan semua kelas secara setara.

# %%
# Siapkan data intent
gt_intents = [gt['intent'] for gt in ground_truth]
pred_intents = [p['intent'] for p in prediksi]

# Hitung metrik menggunakan sklearn.metrics
intent_accuracy = accuracy_score(gt_intents, pred_intents)
intent_precision = precision_score(gt_intents, pred_intents, average='macro', zero_division=0)
intent_recall = recall_score(gt_intents, pred_intents, average='macro', zero_division=0)
intent_f1 = f1_score(gt_intents, pred_intents, average='macro', zero_division=0)

intent_precision_w = precision_score(gt_intents, pred_intents, average='weighted', zero_division=0)
intent_recall_w = recall_score(gt_intents, pred_intents, average='weighted', zero_division=0)
intent_f1_w = f1_score(gt_intents, pred_intents, average='weighted', zero_division=0)

print("=" * 70)
print("EVALUASI IDENTIFIKASI INTENT")
print("=" * 70)
print(f"\n  Accuracy           : {intent_accuracy:.4f}  ({intent_accuracy*100:.2f}%)")
print(f"  Precision (Macro)  : {intent_precision:.4f}  ({intent_precision*100:.2f}%)")
print(f"  Recall (Macro)     : {intent_recall:.4f}  ({intent_recall*100:.2f}%)")
print(f"  F1-score (Macro)   : {intent_f1:.4f}  ({intent_f1*100:.2f}%)")
print(f"\n  Precision (Weight) : {intent_precision_w:.4f}  ({intent_precision_w*100:.2f}%)")
print(f"  Recall (Weight)    : {intent_recall_w:.4f}  ({intent_recall_w*100:.2f}%)")
print(f"  F1-score (Weight)  : {intent_f1_w:.4f}  ({intent_f1_w*100:.2f}%)")

# Classification Report
all_intent_labels = sorted(list(set(gt_intents + pred_intents)))

print("\n" + "-" * 70)
print("Classification Report — Identifikasi Intent")
print("-" * 70)
print(classification_report(
    gt_intents, pred_intents,
    labels=all_intent_labels,
    zero_division=0
))
# Out:
# ======================================================================
# EVALUASI IDENTIFIKASI INTENT
# ======================================================================
#
#   Accuracy           : 0.9500  (95.00%)
#   Precision (Macro)  : 0.9722  (97.22%)
#   Recall (Macro)     : 0.9444  (94.44%)
#   F1-score (Macro)   : 0.9471  (94.71%)
#
#   Precision (Weight) : 0.9625  (96.25%)
#   Recall (Weight)    : 0.9500  (95.00%)
#   F1-score (Weight)  : 0.9452  (94.52%)
#
# ----------------------------------------------------------------------
# Classification Report — Identifikasi Intent
# ----------------------------------------------------------------------
#                          precision    recall  f1-score   support
#
#             CRUD_Barang       1.00      1.00      1.00         3
#   Catat_Penjualan_Cicil       1.00      1.00      1.00         2
#   Catat_Penjualan_Lunas       1.00      1.00      1.00         2
#               Chit_Chat       1.00      1.00      1.00         2
#        Pelunasan_Hutang       1.00      0.50      0.67         2
#    Read_Analitik_Hutang       1.00      1.00      1.00         2
# Read_Analitik_Penjualan       1.00      1.00      1.00         2
# Read_Transaksi_Spesifik       0.75      1.00      0.86         3
# Update_Delete_Transaksi       1.00      1.00      1.00         2
#
#                accuracy                           0.95        20
#               macro avg       0.97      0.94      0.95        20
#            weighted avg       0.96      0.95      0.95        20

# %%
# Heatmap Confusion Matrix — Intent
cm_intent = confusion_matrix(gt_intents, pred_intents, labels=all_intent_labels)

fig, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(
    cm_intent,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=all_intent_labels,
    yticklabels=all_intent_labels,
    linewidths=0.5,
    linecolor='gray',
    cbar_kws={'shrink': 0.75},
    square=True,
    ax=ax
)
ax.set_xlabel('Prediksi Intent', fontsize=12, fontweight='bold')
ax.set_ylabel('Ground Truth Intent', fontsize=12, fontweight='bold')
ax.set_title('Confusion Matrix — Identifikasi Intent\n(Hasil Pembacaan Sistem)', fontsize=13, fontweight='bold', pad=15)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(rotation=0, fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 7. Evaluasi Ekstraksi Entitas
#
# Evaluasi dilakukan terhadap **seluruh jenis entitas**:
# - tanggal, pelanggan, barang, jumlah, satuan, status, nominal, metode_pembayaran
#
# Metode evaluasi:
# - Setiap pasangan (Ground Truth, Prediksi) untuk setiap entitas diklasifikasikan sebagai **Benar** atau **Salah** berdasarkan *exact match*.
# - Metrik TP, FP, FN, TN dihitung untuk menentukan Precision, Recall, dan F1-score.

# %%
def normalize_value(val, field_name):
    """Normalisasi nilai entitas tunggal ke format standar."""
    if val is None:
        return None
    v_str = str(val).strip().lower()
    if v_str in ('none', '', 'nan', 'false'):
        return None
    
    # 1. Metode Pembayaran
    if field_name == 'metode':
        if any(x in v_str for x in ['transfer', 'tf', 'trf']):
            return 'transfer'
        if any(x in v_str for x in ['tunai', 'cash', 'kontan']):
            return 'tunai'
        return v_str
    
    # 2. Nominal Uang
    if field_name == 'nominal':
        v_clean = re.sub(r'[rp\.\s,]', '', v_str)
        v_clean = re.sub(r'(\d+)rb', r'\g<1>000', v_clean)
        v_clean = re.sub(r'(\d+)jt', r'\g<1>000000', v_clean)
        try:
            return str(int(v_clean))
        except ValueError:
            return v_clean
    
    # 3. Jumlah (Angka saja)
    if field_name == 'jumlah':
        m = re.search(r'(\d+)', v_str)
        if m:
            return m.group(1)
        return v_str
        
    # 4. Satuan (Normalisasi slang)
    if field_name == 'satuan':
        if v_str in ('ctn', 'karton'):
            return 'karton'
        if v_str in ('bks', 'bungkus'):
            return 'bungkus'
        return v_str
        
    # 5. Tanggal (Normalisasi separator / ke -)
    if field_name == 'tanggal':
        return v_str.replace('/', '-')

    # 6. Lainnya (barang, pelanggan, status)
    return v_str


def normalize_field(val, field_name):
    """Mengembalikan nilai normalisasi (list untuk barang/jumlah/satuan, string untuk lainnya)."""
    if field_name in ('barang', 'jumlah', 'satuan'):
        if isinstance(val, list):
            items = val
        elif val is None or str(val).strip().lower() in ('none', '', 'nan'):
            items = []
        else:
            items = [val]
        
        normalized_items = []
        for item in items:
            norm = normalize_value(item, field_name)
            if norm is not None:
                normalized_items.append(norm)
        return sorted(normalized_items)
    else:
        return normalize_value(val, field_name)


def to_label_string(val):
    """Mengubah nilai normalisasi ke string unik untuk klasifikasi sklearn."""
    if val is None:
        return "None"
    if isinstance(val, list):
        if len(val) == 0:
            return "None"
        return ", ".join(val)
    return str(val)


# --- 1. Bangun Tabel Detail Evaluasi ---
ENTITY_FIELDS = ['tanggal', 'pelanggan', 'barang', 'jumlah', 'satuan', 'status', 'nominal', 'metode']
detail_rows = []

for i in range(len(test_inputs)):
    gt = ground_truth[i]
    pred = prediksi[i]
    
    for field in ENTITY_FIELDS:
        gt_val = gt.get(field)
        pred_val = pred.get(field)
        
        gt_norm = normalize_field(gt_val, field)
        pred_norm = normalize_field(pred_val, field)
        
        match_status = "Benar" if gt_norm == pred_norm else "Salah"
        
        detail_rows.append({
            "No": i + 1,
            "Input": test_inputs[i],
            "Field": field,
            "Ground Truth": to_label_string(gt_norm),
            "Prediksi": to_label_string(pred_norm),
            "Match": match_status
        })

df_detail = pd.DataFrame(detail_rows)

# Tampilkan opsi baris tanpa batas agar semua baris terlihat
pd.set_option('display.max_rows', 200)

print("=" * 100)
print("TABEL DETAIL EVALUASI EKSTRAKSI ENTITAS (160 Baris)")
print("=" * 100)
print()
df_detail
# Out:
# ====================================================================================================
# TABEL DETAIL EVALUASI EKSTRAKSI ENTITAS (160 Baris)
# ====================================================================================================
#      No                                                                Input      Field            Ground Truth       Prediksi  Match
# 0     1                                                             Halo bot    tanggal                    None           None  Benar
# 1     1                                                             Halo bot  pelanggan                    None       halo bot  Salah
# 2     1                                                             Halo bot     barang                    None           None  Benar
# 3     1                                                             Halo bot     jumlah                    None           None  Benar
# 4     1                                                             Halo bot     satuan                    None           None  Benar
# 5     1                                                             Halo bot     status                    None           None  Benar
# 6     1                                                             Halo bot    nominal                    None           None  Benar
# 7     1                                                             Halo bot     metode                    None           None  Benar
# 8     2                                                         Selamat pagi    tanggal                    None           None  Benar
# 9     2                                                         Selamat pagi  pelanggan                    None        selamat  Salah
# 10    2                                                         Selamat pagi     barang                    None           None  Benar
# 11    2                                                         Selamat pagi     jumlah                    None           None  Benar
# 12    2                                                         Selamat pagi     satuan                    None           None  Benar
# 13    2                                                         Selamat pagi     status                    None           None  Benar
# 14    2                                                         Selamat pagi    nominal                    None           None  Benar
# 15    2                                                         Selamat pagi     metode                    None           None  Benar
# 16    3                                               Cek penjualan hari ini    tanggal              26-06-2026     26-06-2026  Benar
# 17    3                                               Cek penjualan hari ini  pelanggan                    None           None  Benar
# 18    3                                               Cek penjualan hari ini     barang                    None           None  Benar
# 19    3                                               Cek penjualan hari ini     jumlah                    None           None  Benar
# 20    3                                               Cek penjualan hari ini     satuan                    None           None  Benar
# 21    3                                               Cek penjualan hari ini     status                    None           None  Benar
# 22    3                                               Cek penjualan hari ini    nominal                    None           None  Benar
# 23    3                                               Cek penjualan hari ini     metode                    None           None  Benar
# 24    4                                            Total uang masuk hari ini    tanggal              26-06-2026     26-06-2026  Benar
# 25    4                                            Total uang masuk hari ini  pelanggan                    None           None  Benar
# 26    4                                            Total uang masuk hari ini     barang                    None           None  Benar
# 27    4                                            Total uang masuk hari ini     jumlah                    None           None  Benar
# 28    4                                            Total uang masuk hari ini     satuan                    None           None  Benar
# 29    4                                            Total uang masuk hari ini     status                    None         hutang  Salah
# 30    4                                            Total uang masuk hari ini    nominal                    None           None  Benar
# 31    4                                            Total uang masuk hari ini     metode                    None           None  Benar
# 32    5                                            Tampilkan semua transaksi    tanggal                    None           None  Benar
# 33    5                                            Tampilkan semua transaksi  pelanggan                    None           None  Benar
# 34    5                                            Tampilkan semua transaksi     barang                    None           None  Benar
# 35    5                                            Tampilkan semua transaksi     jumlah                    None           None  Benar
# 36    5                                            Tampilkan semua transaksi     satuan                    None           None  Benar
# 37    5                                            Tampilkan semua transaksi     status                    None           None  Benar
# 38    5                                            Tampilkan semua transaksi    nominal                    None           None  Benar
# 39    5                                            Tampilkan semua transaksi     metode                    None           None  Benar
# 40    6                                          Tampilkan transaksi kemarin    tanggal              25-06-2026     25-06-2026  Benar
# 41    6                                          Tampilkan transaksi kemarin  pelanggan                    None           None  Benar
# 42    6                                          Tampilkan transaksi kemarin     barang                    None           None  Benar
# 43    6                                          Tampilkan transaksi kemarin     jumlah                    None           None  Benar
# 44    6                                          Tampilkan transaksi kemarin     satuan                    None           None  Benar
# 45    6                                          Tampilkan transaksi kemarin     status                    None           None  Benar
# 46    6                                          Tampilkan transaksi kemarin    nominal                    None           None  Benar
# 47    6                                          Tampilkan transaksi kemarin     metode                    None           None  Benar
# 48    7                                       Tampilkan transaksi tanggal 21    tanggal              21-06-2026     21-06-2026  Benar
# 49    7                                       Tampilkan transaksi tanggal 21  pelanggan                    None           None  Benar
# 50    7                                       Tampilkan transaksi tanggal 21     barang                    None           None  Benar
# 51    7                                       Tampilkan transaksi tanggal 21     jumlah                    None           None  Benar
# 52    7                                       Tampilkan transaksi tanggal 21     satuan                    None           None  Benar
# 53    7                                       Tampilkan transaksi tanggal 21     status                    None           None  Benar
# 54    7                                       Tampilkan transaksi tanggal 21    nominal                    None           None  Benar
# 55    7                                       Tampilkan transaksi tanggal 21     metode                    None           None  Benar
# 56    8                                                  Cek hutang pak andi    tanggal                    None           None  Benar
# 57    8                                                  Cek hutang pak andi  pelanggan                pak andi       pak andi  Benar
# 58    8                                                  Cek hutang pak andi     barang                    None           None  Benar
# 59    8                                                  Cek hutang pak andi     jumlah                    None           None  Benar
# 60    8                                                  Cek hutang pak andi     satuan                    None           None  Benar
# 61    8                                                  Cek hutang pak andi     status                  hutang         hutang  Benar
# 62    8                                                  Cek hutang pak andi    nominal                    None           None  Benar
# 63    8                                                  Cek hutang pak andi     metode                    None           None  Benar
# 64    9                                                    Tampilkan tagihan    tanggal                    None           None  Benar
# 65    9                                                    Tampilkan tagihan  pelanggan                    None           None  Benar
# 66    9                                                    Tampilkan tagihan     barang                    None           None  Benar
# 67    9                                                    Tampilkan tagihan     jumlah                    None           None  Benar
# 68    9                                                    Tampilkan tagihan     satuan                    None           None  Benar
# 69    9                                                    Tampilkan tagihan     status                    None         hutang  Salah
# 70    9                                                    Tampilkan tagihan    nominal                    None           None  Benar
# 71    9                                                    Tampilkan tagihan     metode                    None           None  Benar
# 72   10                                                 Berapa harga brownis    tanggal                    None           None  Benar
# 73   10                                                 Berapa harga brownis  pelanggan                    None           None  Benar
# 74   10                                                 Berapa harga brownis     barang                 brownis        brownis  Benar
# 75   10                                                 Berapa harga brownis     jumlah                    None           None  Benar
# 76   10                                                 Berapa harga brownis     satuan                    None           None  Benar
# 77   10                                                 Berapa harga brownis     status                    None           None  Benar
# 78   10                                                 Berapa harga brownis    nominal                    None           None  Benar
# 79   10                                                 Berapa harga brownis     metode                    None           None  Benar
# 80   11                         Tambah barang brownis harga 2500 per bungkus    tanggal                    None           None  Benar
# 81   11                         Tambah barang brownis harga 2500 per bungkus  pelanggan                    None            per  Salah
# 82   11                         Tambah barang brownis harga 2500 per bungkus     barang                 brownis        brownis  Benar
# 83   11                         Tambah barang brownis harga 2500 per bungkus     jumlah                    None           None  Benar
# 84   11                         Tambah barang brownis harga 2500 per bungkus     satuan                 bungkus           None  Salah
# 85   11                         Tambah barang brownis harga 2500 per bungkus     status                    None           None  Benar
# 86   11                         Tambah barang brownis harga 2500 per bungkus    nominal                    None           None  Benar
# 87   11                         Tambah barang brownis harga 2500 per bungkus     metode                    None           None  Benar
# 88   12                                         Edit harga permen jadi 14000    tanggal                    None           None  Benar
# 89   12                                         Edit harga permen jadi 14000  pelanggan                    None           None  Benar
# 90   12                                         Edit harga permen jadi 14000     barang                 lolipop        lolipop  Benar
# 91   12                                         Edit harga permen jadi 14000     jumlah                    None           None  Benar
# 92   12                                         Edit harga permen jadi 14000     satuan                    None           None  Benar
# 93   12                                         Edit harga permen jadi 14000     status                    None           None  Benar
# 94   12                                         Edit harga permen jadi 14000    nominal                    None           None  Benar
# 95   12                                         Edit harga permen jadi 14000     metode                    None           None  Benar
# 96   13                                             Hapus transaksi pak ardi    tanggal                    None           None  Benar
# 97   13                                             Hapus transaksi pak ardi  pelanggan                pak ardi       pak ardi  Benar
# 98   13                                             Hapus transaksi pak ardi     barang                    None           None  Benar
# 99   13                                             Hapus transaksi pak ardi     jumlah                    None           None  Benar
# 100  13                                             Hapus transaksi pak ardi     satuan                    None           None  Benar
# 101  13                                             Hapus transaksi pak ardi     status                    None           None  Benar
# 102  13                                             Hapus transaksi pak ardi    nominal                    None           None  Benar
# 103  13                                             Hapus transaksi pak ardi     metode                    None           None  Benar
# 104  14                                     Update transaksi udin jadi lunas    tanggal                    None           None  Benar
# 105  14                                     Update transaksi udin jadi lunas  pelanggan                    udin           udin  Benar
# 106  14                                     Update transaksi udin jadi lunas     barang                    None           None  Benar
# 107  14                                     Update transaksi udin jadi lunas     jumlah                    None           None  Benar
# 108  14                                     Update transaksi udin jadi lunas     satuan                    None           None  Benar
# 109  14                                     Update transaksi udin jadi lunas     status                   lunas          lunas  Benar
# 110  14                                     Update transaksi udin jadi lunas    nominal                    None           None  Benar
# 111  14                                     Update transaksi udin jadi lunas     metode                    None           None  Benar
# 112  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai    tanggal              26-06-2026     26-06-2026  Benar
# 113  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai  pelanggan                    budi           budi  Benar
# 114  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai     barang                 bembeng        bembeng  Benar
# 115  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai     jumlah                      40             40  Benar
# 116  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai     satuan                  karton         karton  Benar
# 117  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai     status                   lunas          lunas  Benar
# 118  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai    nominal                    None           None  Benar
# 119  15                       Hari ini Budi ambil bembeng 40 ctn lunas tunai     metode                   tunai          tunai  Benar
# 120  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf    tanggal              25-06-2026     25-06-2026  Benar
# 121  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf  pelanggan                    udin           udin  Benar
# 122  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf     barang                   meses          meses  Benar
# 123  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf     jumlah                      20             20  Benar
# 124  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf     satuan                  karton         karton  Benar
# 125  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf     status                 dicicil        dicicil  Benar
# 126  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf    nominal                  200000         200000  Benar
# 127  16                    Kemarin Udin ambil meses 20 ctn dicicil 200000 tf     metode                transfer       transfer  Benar
# 128  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn    tanggal                 06-2026           None  Salah
# 129  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn  pelanggan                    budi    o62o26 budi  Salah
# 130  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn     barang   bembeng, meses, willo        bembeng  Salah
# 131  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn     jumlah             100, 20, 40             40  Salah
# 132  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn     satuan  karton, karton, karton         karton  Salah
# 133  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn     status                    None           None  Benar
# 134  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn    nominal                    None           None  Benar
# 135  17  06-2026 Nama : Budi budis bembeng 40 ctn meses 20 ctn willo 100 ctn     metode                    None           None  Benar
# 136  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer    tanggal              21-04-2026           None  Salah
# 137  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer  pelanggan                    andi  2lo42o26 andi  Salah
# 138  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer     barang                 lolipop        lolipop  Benar
# 139  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer     jumlah                      10             10  Benar
# 140  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer     satuan                     dus            dus  Benar
# 141  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer     status                 dicicil        dicicil  Benar
# 142  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer    nominal                   50000          50000  Benar
# 143  18           21/04/2026 Andi ambil permen 10 dus dicicil 50000 transfer     metode                transfer       transfer  Benar
# 144  19                                     Zio bayar hutang 270000 transfer    tanggal                    None           None  Benar
# 145  19                                     Zio bayar hutang 270000 transfer  pelanggan                     zio            zio  Benar
# 146  19                                     Zio bayar hutang 270000 transfer     barang                    None           None  Benar
# 147  19                                     Zio bayar hutang 270000 transfer     jumlah                    None           None  Benar
# 148  19                                     Zio bayar hutang 270000 transfer     satuan                    None           None  Benar
# 149  19                                     Zio bayar hutang 270000 transfer     status                 dicicil        dicicil  Benar
# 150  19                                     Zio bayar hutang 270000 transfer    nominal                  270000         270000  Benar
# 151  19                                     Zio bayar hutang 270000 transfer     metode                transfer       transfer  Benar
# 152  20                                   Tambahan bayar pak andi 50rb tunai    tanggal                    None           None  Benar
# 153  20                                   Tambahan bayar pak andi 50rb tunai  pelanggan                pak andi       pak andi  Benar
# 154  20                                   Tambahan bayar pak andi 50rb tunai     barang                    None           None  Benar
# 155  20                                   Tambahan bayar pak andi 50rb tunai     jumlah                    None           None  Benar
# 156  20                                   Tambahan bayar pak andi 50rb tunai     satuan                    None           None  Benar
# 157  20                                   Tambahan bayar pak andi 50rb tunai     status                 dicicil        dicicil  Benar
# 158  20                                   Tambahan bayar pak andi 50rb tunai    nominal                   50000          50000  Benar
# 159  20                                   Tambahan bayar pak andi 50rb tunai     metode                   tunai          tunai  Benar

# %%
# --- 2. Hitung Metrik Per Field ---
per_field_metrics = []
field_predictions = {}

print("=" * 80)
print("EVALUASI KINERJA EKSTRAKSI ENTITAS PER FIELD")
print("=" * 80)
print()

for field in ENTITY_FIELDS:
    df_field = df_detail[df_detail["Field"] == field]
    
    gt_labels = df_field["Ground Truth"].tolist()
    pred_labels = df_field["Prediksi"].tolist()
    
    field_predictions[field] = (gt_labels, pred_labels)
    
    # Hitung TP, FP, FN manual berdasarkan exact match
    tp = fp = fn = tn = 0
    for gt_lbl, pred_lbl in zip(gt_labels, pred_labels):
        g_exists = gt_lbl != "None"
        p_exists = pred_lbl != "None"
        
        if g_exists and p_exists:
            if gt_lbl == pred_lbl:
                tp += 1
            else:
                fp += 1
                fn += 1
        elif not g_exists and not p_exists:
            tn += 1
        elif p_exists and not g_exists:
            fp += 1
        elif g_exists and not p_exists:
            fn += 1
            
    # Hitung metrik menggunakan sklearn.metrics
    acc = accuracy_score(gt_labels, pred_labels)
    prec_macro = precision_score(gt_labels, pred_labels, average='macro', zero_division=0)
    rec_macro = recall_score(gt_labels, pred_labels, average='macro', zero_division=0)
    f1_macro = f1_score(gt_labels, pred_labels, average='macro', zero_division=0)
    
    prec_weighted = precision_score(gt_labels, pred_labels, average='weighted', zero_division=0)
    rec_weighted = recall_score(gt_labels, pred_labels, average='weighted', zero_division=0)
    f1_weighted = f1_score(gt_labels, pred_labels, average='weighted', zero_division=0)
    
    per_field_metrics.append({
        "Field": field,
        "Accuracy": acc,
        "Precision_Macro": prec_macro,
        "Recall_Macro": rec_macro,
        "F1_Macro": f1_macro,
        "Precision_Weighted": prec_weighted,
        "Recall_Weighted": rec_weighted,
        "F1_Weighted": f1_weighted,
        "TP": tp, "FP": fp, "FN": fn, "TN": tn
    })
    
    print(f"[{field.upper()}]")
    print(f"  TP: {tp}, FP: {fp}, FN: {fn}, TN: {tn}")
    print(f"  Accuracy: {acc:.4f}  ({acc*100:.2f}%)")
    print(f"  Precision: {prec_macro:.4f} (Macro) | {prec_weighted:.4f} (Weighted)")
    print(f"  Recall:    {rec_macro:.4f} (Macro) | {rec_weighted:.4f} (Weighted)")
    print(f"  F1-score:  {f1_macro:.4f} (Macro) | {f1_weighted:.4f} (Weighted)")
    print("-" * 50)

# --- 3. Buat Tabel Ringkasan Per Field ---
summary_rows = []
for m in per_field_metrics:
    summary_rows.append({
        "Field": m["Field"],
        "Accuracy": f"{m['Accuracy']*100:.2f}%",
        "Precision": f"{m['Precision_Macro']*100:.2f}%",
        "Recall": f"{m['Recall_Macro']*100:.2f}%",
        "F1-score": f"{m['F1_Macro']*100:.2f}%"
    })

# Hitung Rata-rata (Macro & Weighted)
avg_acc = np.mean([m["Accuracy"] for m in per_field_metrics])
avg_prec_macro = np.mean([m["Precision_Macro"] for m in per_field_metrics])
avg_rec_macro = np.mean([m["Recall_Macro"] for m in per_field_metrics])
avg_f1_macro = np.mean([m["F1_Macro"] for m in per_field_metrics])

avg_prec_weighted = np.mean([m["Precision_Weighted"] for m in per_field_metrics])
avg_rec_weighted = np.mean([m["Recall_Weighted"] for m in per_field_metrics])
avg_f1_weighted = np.mean([m["F1_Weighted"] for m in per_field_metrics])

summary_rows.append({
    "Field": "Macro Average",
    "Accuracy": f"{avg_acc*100:.2f}%",
    "Precision": f"{avg_prec_macro*100:.2f}%",
    "Recall": f"{avg_rec_macro*100:.2f}%",
    "F1-score": f"{avg_f1_macro*100:.2f}%"
})

summary_rows.append({
    "Field": "Weighted Average",
    "Accuracy": f"{avg_acc*100:.2f}%",
    "Precision": f"{avg_prec_weighted*100:.2f}%",
    "Recall": f"{avg_rec_weighted*100:.2f}%",
    "F1-score": f"{avg_f1_weighted*100:.2f}%"
})

df_summary_fields = pd.DataFrame(summary_rows)

print("\n" + "=" * 80)
print("TABEL RINGKASAN EVALUASI PER FIELD")
print("=" * 80)
print()
df_summary_fields
# Out:
# ================================================================================
# EVALUASI KINERJA EKSTRAKSI ENTITAS PER FIELD
# ================================================================================
#
# [TANGGAL]
#   TP: 6, FP: 0, FN: 2, TN: 12
#   Accuracy: 0.9000  (90.00%)
#   Precision: 0.6429 (Macro) | 0.8143 (Weighted)
#   Recall:    0.6667 (Macro) | 0.9000 (Weighted)
#   F1-score:  0.6538 (Macro) | 0.8538 (Weighted)
# --------------------------------------------------
# [PELANGGAN]
#   TP: 7, FP: 5, FN: 2, TN: 8
#   Accuracy: 0.7500  (75.00%)
#   Precision: 0.5000 (Macro) | 0.9500 (Weighted)
#   Recall:    0.4356 (Macro) | 0.7500 (Weighted)
#   F1-score:  0.4591 (Macro) | 0.8298 (Weighted)
# --------------------------------------------------
# [BARANG]
#   TP: 6, FP: 1, FN: 1, TN: 13
#   Accuracy: 0.9500  (95.00%)
#   Precision: 0.7500 (Macro) | 0.9250 (Weighted)
#   Recall:    0.8333 (Macro) | 0.9500 (Weighted)
#   F1-score:  0.7778 (Macro) | 0.9333 (Weighted)
# --------------------------------------------------
# [JUMLAH]
#   TP: 3, FP: 1, FN: 1, TN: 16
#   Accuracy: 0.9500  (95.00%)
#   Precision: 0.7000 (Macro) | 0.9250 (Weighted)
#   Recall:    0.8000 (Macro) | 0.9500 (Weighted)
#   F1-score:  0.7333 (Macro) | 0.9333 (Weighted)
# --------------------------------------------------
# [SATUAN]
#   TP: 3, FP: 1, FN: 2, TN: 15
#   Accuracy: 0.9000  (90.00%)
#   Precision: 0.5208 (Macro) | 0.8198 (Weighted)
#   Recall:    0.6000 (Macro) | 0.9000 (Weighted)
#   F1-score:  0.5535 (Macro) | 0.8558 (Weighted)
# --------------------------------------------------
# [STATUS]
#   TP: 7, FP: 2, FN: 0, TN: 11
#   Accuracy: 0.9000  (90.00%)
#   Precision: 0.8333 (Macro) | 0.9667 (Weighted)
#   Recall:    0.9615 (Macro) | 0.9000 (Weighted)
#   F1-score:  0.8542 (Macro) | 0.9208 (Weighted)
# --------------------------------------------------
# [NOMINAL]
#   TP: 4, FP: 0, FN: 0, TN: 16
#   Accuracy: 1.0000  (100.00%)
#   Precision: 1.0000 (Macro) | 1.0000 (Weighted)
#   Recall:    1.0000 (Macro) | 1.0000 (Weighted)
#   F1-score:  1.0000 (Macro) | 1.0000 (Weighted)
# --------------------------------------------------
# [METODE]
#   TP: 5, FP: 0, FN: 0, TN: 15
#   Accuracy: 1.0000  (100.00%)
#   Precision: 1.0000 (Macro) | 1.0000 (Weighted)
#   Recall:    1.0000 (Macro) | 1.0000 (Weighted)
#   F1-score:  1.0000 (Macro) | 1.0000 (Weighted)
# --------------------------------------------------
#
# ================================================================================
# TABEL RINGKASAN EVALUASI PER FIELD
# ================================================================================
#               Field Accuracy Precision   Recall F1-score
# 0           tanggal   90.00%    64.29%   66.67%   65.38%
# 1         pelanggan   75.00%    50.00%   43.56%   45.91%
# 2            barang   95.00%    75.00%   83.33%   77.78%
# 3            jumlah   95.00%    70.00%   80.00%   73.33%
# 4            satuan   90.00%    52.08%   60.00%   55.35%
# 5            status   90.00%    83.33%   96.15%   85.42%
# 6           nominal  100.00%   100.00%  100.00%  100.00%
# 7            metode  100.00%   100.00%  100.00%  100.00%
# 8     Macro Average   91.88%    74.34%   78.71%   75.40%
# 9  Weighted Average   91.88%    92.51%   91.88%   91.59%

# %%
# --- 4. Visualisasi Confusion Matrix untuk Field Status dan Metode ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

for idx, field in enumerate(['status', 'metode']):
    gt_list, pred_list = field_predictions[field]
    labels = sorted(list(set(gt_list + pred_list)))
    
    cm = confusion_matrix(gt_list, pred_list, labels=labels)
    
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Greens',
        xticklabels=labels,
        yticklabels=labels,
        linewidths=0.5,
        linecolor='gray',
        square=True,
        annot_kws={'fontsize': 12, 'fontweight': 'bold'},
        ax=axes[idx]
    )
    axes[idx].set_xlabel('Prediksi', fontsize=11, fontweight='bold')
    axes[idx].set_ylabel('Ground Truth', fontsize=11, fontweight='bold')
    axes[idx].set_title(f'Confusion Matrix — Field {field.upper()}', fontsize=12, fontweight='bold', pad=10)

plt.suptitle('Evaluasi Ekstraksi Entitas — Performa Klasifikasi Nilai Field', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Cell ini dikosongkan karena visualisasi confusion matrix telah dipindah ke Cell 18
# dan visualisasi Ada/Tidak Ada telah dihapus sesuai ketentuan.

# %% [markdown]
# ---
# ## 8. Ringkasan Hasil

# %%
# Tabel Ringkasan Hasil Akhir
summary_data = {
    'Komponen': ['Identifikasi Intent', 'Ekstraksi Entitas'],
    'Accuracy': [
        f"{intent_accuracy*100:.2f}%",
        f"{avg_acc*100:.2f}%"
    ],
    'Precision': [
        f"{intent_precision*100:.2f}%",
        f"{avg_prec_macro*100:.2f}%"
    ],
    'Recall': [
        f"{intent_recall*100:.2f}%",
        f"{avg_rec_macro*100:.2f}%"
    ],
    'F1-score': [
        f"{intent_f1*100:.2f}%",
        f"{avg_f1_macro*100:.2f}%"
    ]
}

df_summary = pd.DataFrame(summary_data)

print("=" * 70)
print("RINGKASAN HASIL PENGUJIAN AKHIR")
print("=" * 70)
print()
print("Seluruh nilai dihitung otomatis menggunakan sklearn.metrics")
print("berdasarkan hasil pembacaan sistem yang sebenarnya.")
print()
df_summary
# Out:
# ======================================================================
# RINGKASAN HASIL PENGUJIAN AKHIR
# ======================================================================
#
# Seluruh nilai dihitung otomatis menggunakan sklearn.metrics
# berdasarkan hasil pembacaan sistem yang sebenarnya.
#               Komponen Accuracy Precision  Recall F1-score
# 0  Identifikasi Intent   95.00%    97.22%  94.44%   94.71%
# 1    Ekstraksi Entitas   91.88%    74.34%  78.71%   75.40%

# %%
# Visualisasi Bar Chart Ringkasan
fig, ax = plt.subplots(figsize=(10, 5.5))

metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']
intent_vals = [intent_accuracy*100, intent_precision*100, intent_recall*100, intent_f1*100]
entity_vals = [avg_acc*100, avg_prec_macro*100, avg_rec_macro*100, avg_f1_macro*100]

x = np.arange(len(metrics))
width = 0.32

bars1 = ax.bar(x - width/2, intent_vals, width, label='Identifikasi Intent',
               color='#3B82F6', edgecolor='white', linewidth=0.8)
bars2 = ax.bar(x + width/2, entity_vals, width, label='Ekstraksi Entitas',
               color='#F59E0B', edgecolor='white', linewidth=0.8)

ax.set_ylabel('Persentase (%)', fontsize=12, fontweight='bold')
ax.set_title('Ringkasan Hasil Pengujian Sistem NLP\n(Rule-Based & Fuzzy String Matching)',
             fontsize=13, fontweight='bold', pad=10)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=11)
ax.legend(fontsize=10, loc='upper right')
ax.set_ylim(0, 115)
ax.grid(axis='y', alpha=0.3)

# Label nilai di atas bar
for bar in bars1:
    h = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, h + 1.5, f'{h:.1f}%',
            ha='center', va='bottom', fontsize=9, fontweight='bold', color='#1E40AF')

for bar in bars2:
    h = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, h + 1.5, f'{h:.1f}%',
            ha='center', va='bottom', fontsize=9, fontweight='bold', color='#92400E')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 9. Kesimpulan
#
# Kesimpulan dibuat **otomatis** berdasarkan hasil perhitungan evaluasi.

# %%
# ============================================================
# KESIMPULAN — Dibuat otomatis dari hasil perhitungan
# ============================================================

intent_benar = sum(1 for g, p in zip(gt_intents, pred_intents) if g == p)
intent_salah = len(gt_intents) - intent_benar

# Total kecocokan untuk seluruh 160 entitas detail
entitas_total_baris = len(df_detail)
entitas_benar_baris = len(df_detail[df_detail["Match"] == "Benar"])
entitas_salah_baris = entitas_total_baris - entitas_benar_baris

print("=" * 70)
print("KESIMPULAN")
print("=" * 70)

print(f"""
Hasil pengujian menunjukkan bahwa sistem NLP berbasis Rule-Based dan
Fuzzy String Matching berhasil mengidentifikasi intent dengan:
  - Accuracy  : {intent_accuracy*100:.2f}%
  - Precision : {intent_precision*100:.2f}%
  - Recall    : {intent_recall*100:.2f}%
  - F1-score  : {intent_f1*100:.2f}%

Dari {len(gt_intents)} data uji, {intent_benar} intent teridentifikasi dengan
benar dan {intent_salah} intent tidak sesuai dengan Ground Truth.

Pada ekstraksi entitas (nilai rata-rata dari 8 field) diperoleh:
  - Accuracy  : {avg_acc*100:.2f}%
  - Precision : {avg_prec_macro*100:.2f}%
  - Recall    : {avg_rec_macro*100:.2f}%
  - F1-score  : {avg_f1_macro*100:.2f}%

Dari {entitas_total_baris} baris pengecekan entitas (20 data uji × 8 field),
{entitas_benar_baris} entitas terbukti cocok secara nilai (exact match) dan
{entitas_salah_baris} entitas mengalami ketidakcocokan.

Nilai tersebut diperoleh dari hasil pembacaan sistem secara langsung
tanpa adanya penyesuaian terhadap Ground Truth.""")

# Detail intent yang salah
salah_list = []
for i, (g, p) in enumerate(zip(gt_intents, pred_intents)):
    if g != p:
        salah_list.append((i+1, test_inputs[i], g, p))

if salah_list:
    print(f"\nDetail intent yang tidak sesuai ({len(salah_list)} kasus):")
    print("-" * 70)
    for no, inp, gt, pr in salah_list:
        inp_display = inp[:50] + '...' if len(inp) > 50 else inp
        print(f"  [{no:02d}] \"{inp_display}\"")
        print(f"       Ground Truth : {gt}")
        print(f"       Prediksi     : {pr}")

# Detail entitas yang salah
df_salah_entitas = df_detail[df_detail["Match"] == "Salah"]
if not df_salah_entitas.empty:
    print(f"\nDetail entitas yang tidak cocok ({len(df_salah_entitas)} kasus):")
    print("-" * 70)
    for idx, row in df_salah_entitas.iterrows():
        print(f"  [{row['No']:02d}] {row['Field']:<12s}: GT={row['Ground Truth']:<25s} Pred={row['Prediksi']}")

print("\n" + "=" * 70)
print("Seluruh proses pengujian dapat direproduksi dengan")
print("menjalankan ulang notebook ini di Jupyter Lab.")
print("=" * 70)
# Out:
# ======================================================================
# KESIMPULAN
# ======================================================================
#
# Hasil pengujian menunjukkan bahwa sistem NLP berbasis Rule-Based dan
# Fuzzy String Matching berhasil mengidentifikasi intent dengan:
#   - Accuracy  : 95.00%
#   - Precision : 97.22%
#   - Recall    : 94.44%
#   - F1-score  : 94.71%
#
# Dari 20 data uji, 19 intent teridentifikasi dengan
# benar dan 1 intent tidak sesuai dengan Ground Truth.
#
# Pada ekstraksi entitas (nilai rata-rata dari 8 field) diperoleh:
#   - Accuracy  : 91.88%
#   - Precision : 74.34%
#   - Recall    : 78.71%
#   - F1-score  : 75.40%
#
# Dari 160 baris pengecekan entitas (20 data uji × 8 field),
# 147 entitas terbukti cocok secara nilai (exact match) dan
# 13 entitas mengalami ketidakcocokan.
#
# Nilai tersebut diperoleh dari hasil pembacaan sistem secara langsung
# tanpa adanya penyesuaian terhadap Ground Truth.
#
# Detail intent yang tidak sesuai (1 kasus):
# ----------------------------------------------------------------------
#   [19] "Zio bayar hutang 270000 transfer"
#        Ground Truth : Pelunasan_Hutang
#        Prediksi     : Read_Transaksi_Spesifik
#
# Detail entitas yang tidak cocok (13 kasus):
# ----------------------------------------------------------------------
#   [01] pelanggan   : GT=None                      Pred=halo bot
#   [02] pelanggan   : GT=None                      Pred=selamat
#   [04] status      : GT=None                      Pred=hutang
#   [09] status      : GT=None                      Pred=hutang
#   [11] pelanggan   : GT=None                      Pred=per
#   [11] satuan      : GT=bungkus                   Pred=None
#   [17] tanggal     : GT=06-2026                   Pred=None
#   [17] pelanggan   : GT=budi                      Pred=o62o26 budi
#   [17] barang      : GT=bembeng, meses, willo     Pred=bembeng
#   [17] jumlah      : GT=100, 20, 40               Pred=40
#   [17] satuan      : GT=karton, karton, karton    Pred=karton
#   [18] tanggal     : GT=21-04-2026                Pred=None
#   [18] pelanggan   : GT=andi                      Pred=2lo42o26 andi
#
# ======================================================================
# Seluruh proses pengujian dapat direproduksi dengan
# menjalankan ulang notebook ini di Jupyter Lab.
# ======================================================================
